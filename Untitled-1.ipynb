# %%
import numpy as np 
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("Sleep_health_and_lifestyle_dataset.csv")
df.head()
# Out:
#    Person ID Gender  Age            Occupation  Sleep Duration  \
# 0          1   Male   27     Software Engineer             6.1
# 1          2   Male   28                Doctor             6.2
# 2          3   Male   28                Doctor             6.2
# 3          4   Male   28  Sales Representative             5.9
# 4          5   Male   28  Sales Representative             5.9
#
#    Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 0                 6                       42             6   Overweight
# 1                 6                       60             8       Normal
# 2                 6                       60             8       Normal
# 3                 4                       30             8        Obese
# 4                 4                       30             8        Obese
#
#   Blood Pressure  Heart Rate  Daily Steps Sleep Disorder
# 0         126/83          77         4200           None
# 1         125/80          75        10000           None
# 2         125/80          75        10000           None
# 3         140/90          85         3000    Sleep Apnea
# 4         140/90          85         3000    Sleep Apnea

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 374 entries, 0 to 373
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Person ID                374 non-null    int64
#  1   Gender                   374 non-null    object
#  2   Age                      374 non-null    int64
#  3   Occupation               374 non-null    object
#  4   Sleep Duration           374 non-null    float64
#  5   Quality of Sleep         374 non-null    int64
#  6   Physical Activity Level  374 non-null    int64
#  7   Stress Level             374 non-null    int64
#  8   BMI Category             374 non-null    object
#  9   Blood Pressure           374 non-null    object
#  10  Heart Rate               374 non-null    int64
#  11  Daily Steps              374 non-null    int64
#  12  Sleep Disorder           374 non-null    object
# dtypes: float64(1), int64(7), object(5)
# memory usage: 38.1+ KB

# %%
# mengecek keberadaan NaN values
nan_colums = df.columns[df.isnull().any()]
nan_count = df.columns[df.isnull().sum()]

if len(nan_colums) > 0:
    print("Kolom yang berisi NaN values:")
    for column in nan_colums:
        print(f"{column}: {nan_count[column]} NaN values")
else:
    print("NaN values tidak ditemukan")
# Out:
# NaN values tidak ditemukan

# %%
df[['systolic', 'diastolic']] = (df['Blood Pressure']
                                 .str.split('/', expand=True)
                                 .astype(int)
                                )
df.head()
# Out:
#    Person ID Gender  Age            Occupation  Sleep Duration  \
# 0          1   Male   27     Software Engineer             6.1
# 1          2   Male   28                Doctor             6.2
# 2          3   Male   28                Doctor             6.2
# 3          4   Male   28  Sales Representative             5.9
# 4          5   Male   28  Sales Representative             5.9
#
#    Quality of Sleep  Physical Activity Level  Stress Level BMI Category  \
# 0                 6                       42             6   Overweight
# 1                 6                       60             8       Normal
# 2                 6                       60             8       Normal
# 3                 4                       30             8        Obese
# 4                 4                       30             8        Obese
#
#   Blood Pressure  Heart Rate  Daily Steps Sleep Disorder  systolic  diastolic
# 0         126/83          77         4200           None       126         83
# 1         125/80          75        10000           None       125         80
# 2         125/80          75        10000           None       125         80
# 3         140/90          85         3000    Sleep Apnea       140         90
# 4         140/90          85         3000    Sleep Apnea       140         90

# %%
def filter(x):
    if x <= 60000:
        return 'low'
    if (x > 60000 and x <= 120000):
        return 'medium'
    if x > 120000:
        return 'high'
#applying the filter function to 'Salary' column 
df['category'] = df['Salary'].apply(filter)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[35], line 1
# ----> 1 if df['systolic'].all().values >= 90 and df['systolic'].all().values <= 120 and df['diastolic'].all().values >= 60 and df['systolic'].all().values <= 80:
#       2     df['Blood Pressure'].values = "normal"
#       4 df.head()
#
# AttributeError: 'numpy.bool_' object has no attribute 'values'

# %%
df = df.drop('Person ID', axis = 1)
df.head()
# Out:
#   Gender  Age            Occupation  Sleep Duration  Quality of Sleep  \
# 0   Male   27     Software Engineer             6.1                 6
# 1   Male   28                Doctor             6.2                 6
# 2   Male   28                Doctor             6.2                 6
# 3   Male   28  Sales Representative             5.9                 4
# 4   Male   28  Sales Representative             5.9                 4
#
#    Physical Activity Level  Stress Level BMI Category  Heart Rate  \
# 0                       42             6   Overweight          77
# 1                       60             8       Normal          75
# 2                       60             8       Normal          75
# 3                       30             8        Obese          85
# 4                       30             8        Obese          85
#
#    Daily Steps Sleep Disorder  systolic  diastolic
# 0         4200           None       126         83
# 1        10000           None       125         80
# 2        10000           None       125         80
# 3         3000    Sleep Apnea       140         90
# 4         3000    Sleep Apnea       140         90

# %%
# Function untuk encode
def encoding_time(colums):
    mapping_thing = {}

    encoded_datas = []
    counter = 1

    for c in colums:
        if c not in mapping_thing:
            mapping_thing[c] = counter
            counter += 1

        encoded_data = mapping_thing[c]
        encoded_datas.append(encoded_data)
        
    return encoded_datas

# %%
array_Gender = df['Gender'].unique().tolist()
encode_Gender = encoding_time(array_Gender)
df['Gender'] = df['Gender'].replace(array_Gender, encode_Gender)

array_Occupation = df['Occupation'].unique().tolist()
encode_Occupation = encoding_time(array_Occupation)
df['Occupation'] = df['Occupation'].replace(array_Occupation, encode_Occupation)

array_BMICategory = df['BMI Category'].unique().tolist()
encode_BMICategory = encoding_time(array_BMICategory)
df['BMI Category'] = df['BMI Category'].replace(array_BMICategory, encode_BMICategory)

array_SleepDisorder = df['Sleep Disorder'].unique().tolist()
encode_SleepDisorder = encoding_time(array_SleepDisorder)
df['Sleep Disorder'] = df['Sleep Disorder'].replace(array_SleepDisorder, encode_SleepDisorder)

# %%
df.head()
# Out:
#    Gender  Age  Occupation  Sleep Duration  Quality of Sleep  \
# 0       1   27           1             6.1                 6
# 1       1   28           2             6.2                 6
# 2       1   28           2             6.2                 6
# 3       1   28           3             5.9                 4
# 4       1   28           3             5.9                 4
#
#    Physical Activity Level  Stress Level  BMI Category  Heart Rate  \
# 0                       42             6             1          77
# 1                       60             8             2          75
# 2                       60             8             2          75
# 3                       30             8             3          85
# 4                       30             8             3          85
#
#    Daily Steps  Sleep Disorder  systolic  diastolic
# 0         4200               1       126         83
# 1        10000               1       125         80
# 2        10000               1       125         80
# 3         3000               2       140         90
# 4         3000               2       140         90

# %%
df.describe()
# Out:
#            Gender         Age  Occupation  Sleep Duration  Quality of Sleep  \
# count  374.000000  374.000000  374.000000      374.000000        374.000000
# mean     1.494652   42.184492    5.614973        7.132086          7.312834
# std      0.500641    8.673133    2.560033        0.795657          1.196956
# min      1.000000   27.000000    1.000000        5.800000          4.000000
# 25%      1.000000   35.250000    4.000000        6.400000          6.000000
# 50%      1.000000   43.000000    5.000000        7.200000          7.000000
# 75%      2.000000   50.000000    7.000000        7.800000          8.000000
# max      2.000000   59.000000   11.000000        8.500000          9.000000
#
#        Physical Activity Level  Stress Level  BMI Category  Heart Rate  \
# count               374.000000    374.000000    374.000000  374.000000
# mean                 59.171123      5.385027      1.743316   70.165775
# std                  20.830804      1.774526      0.763368    4.135676
# min                  30.000000      3.000000      1.000000   65.000000
# 25%                  45.000000      4.000000      1.000000   68.000000
# 50%                  60.000000      5.000000      2.000000   70.000000
# 75%                  75.000000      7.000000      2.000000   72.000000
# max                  90.000000      8.000000      4.000000   86.000000
#
#         Daily Steps  Sleep Disorder    systolic   diastolic
# count    374.000000      374.000000  374.000000  374.000000
# mean    6816.844920        1.620321  128.553476   84.649733
# std     1617.915679        0.805620    7.748118    6.161611
# min     3000.000000        1.000000  115.000000   75.000000
# 25%     5600.000000        1.000000  125.000000   80.000000
# 50%     7000.000000        1.000000  130.000000   85.000000
# 75%     8000.000000        2.000000  135.000000   90.000000
# max    10000.000000        3.000000  142.000000   95.000000

# %%
sns.pairplot(data=df, hue="Sleep Disorder")
plt.show()

# %%
plt.subplots(figsize=(7,5))
sns.heatmap(df.corr(), vmin=-1, vmax=1, cmap="RdBu", annot=True)
plt.show()

# %%
# Assign the predictor and target variables
# Predictor (independent) Variabel Age & Salary
X = df.loc[:, df.columns != 'Sleep Disorder'].values

# Target (dependent) Variabel Purchased
y = df['Sleep Disorder'].values
# X.head()

# %%
from sklearn.model_selection import train_test_split

# X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.30, random_state=17)
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.20, random_state=1)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 374 entries, 0 to 373
# Data columns (total 13 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Gender                   374 non-null    int64
#  1   Age                      374 non-null    int64
#  2   Occupation               374 non-null    int64
#  3   Sleep Duration           374 non-null    float64
#  4   Quality of Sleep         374 non-null    int64
#  5   Physical Activity Level  374 non-null    int64
#  6   Stress Level             374 non-null    int64
#  7   BMI Category             374 non-null    int64
#  8   Heart Rate               374 non-null    int64
#  9   Daily Steps              374 non-null    int64
#  10  Sleep Disorder           374 non-null    int64
#  11  systolic                 374 non-null    int32
#  12  diastolic                374 non-null    int32
# dtypes: float64(1), int32(2), int64(10)
# memory usage: 35.2 KB

# %%
from sklearn.ensemble import RandomForestClassifier

import warnings
warnings.simplefilter(action="ignore")

rf_model = RandomForestClassifier(random_state=1)
rf_model.fit(X_train, y_train)
y_pred = rf_model.predict(X_test)

# %%
from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score, roc_auc_score, classification_report, confusion_matrix

print(f"Accuracy: {round(accuracy_score(y_pred, y_test), 4)}")
print(f"Recall: {recall_score(y_pred, y_test)}")
print(f"Precision: {round(precision_score(y_pred, y_test), 4)}")
print(f"F1: {round(f1_score(y_pred, y_test), 4)}")
print(f"Auc: {round(roc_auc_score(y_pred, y_test), 4)}")

print(classification_report(y_pred, y_test))
# Out:
# Accuracy: 0.8933
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[33], line 4
#       1 from sklearn.metrics import accuracy_score, recall_score, precision_score, f1_score, roc_auc_score, classification_report
#       3 print(f"Accuracy: {round(accuracy_score(y_pred, y_test), 4)}")
# ----> 4 print(f"Recall: {recall_score(y_pred, y_test)}")
#       5 print(f"Precision: {round(precision_score(y_pred,y_test), 4)}")
#       6 print(f"F1: {round(f1_score(y_pred,y_test), 4)}")
#
# File c:\Users\davina\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:2098, in recall_score(y_true, y_pred, labels, pos_label, average, sample_weight, zero_division)
#    1967 def recall_score(
#    1968     y_true,
#    1969     y_pred,
#    (...)
#    1975     zero_division="warn",
#    1976 ):
#    1977     """Compute the recall.
#    1978
#    1979     The recall is the ratio ``tp / (tp + fn)`` where ``tp`` is the number of
#    (...)
#    2096     array([1. , 1. , 0.5])
#    2097     """
# -> 2098     _, r, _, _ = precision_recall_fscore_support(
#    2099         y_true,
#    2100         y_pred,
#    2101         labels=labels,
#    2102         pos_label=pos_label,
#    2103         average=average,
#    2104         warn_for=("recall",),
#    2105         sample_weight=sample_weight,
#    2106         zero_division=zero_division,
#    2107     )
#    2108     return r
#
# File c:\Users\davina\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1573, in precision_recall_fscore_support(y_true, y_pred, beta, labels, pos_label, average, warn_for, sample_weight, zero_division)
#    1571 if beta < 0:
#    1572     raise ValueError("beta should be >=0 in the F-beta score")
# -> 1573 labels = _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#    1575 # Calculate tp_sum, pred_sum, true_sum ###
#    1576 samplewise = average == "samples"
#
# File c:\Users\davina\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1391, in _check_set_wise_labels(y_true, y_pred, average, labels, pos_label)
#    1389         if y_type == "multiclass":
#    1390             average_options.remove("samples")
# -> 1391         raise ValueError(
#    1392             "Target is %s but average='binary'. Please "
#    1393             "choose another average setting, one of %r." % (y_type, average_options)
#    1394         )
#    1395 elif pos_label not in (None, 1):
#    1396     warnings.warn(
#    1397         "Note that pos_label (set to %r) is ignored when "
#    1398         "average != 'binary' (got %r). You may use "
#    (...)
#    1401         UserWarning,
#    1402     )
#
# ValueError: Target is multiclass but average='binary'. Please choose another average setting, one of [None, 'micro', 'macro', 'weighted'].

# %%
ihsg_pred = rf_model.predict([[]])
print('Predict : {:.0f}'.format(ihsg_pred[0]))
